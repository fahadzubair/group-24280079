# %%
# !pip3 install great_expectations
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 28.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: altair
#     Found existing installation: altair 5.5.0
#     Uninstalling altair-5.5.0:
#       Successfully uninstalled altair-5.5.0
# ...

# %%
import great_expectations as gx
import pandas as pd
import praw

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/great-expectations/gx_tutorials/main/data/yellow_tripdata_sample_2019-01.csv"
)

# %% [markdown]
# # Using Great Expectations

# %%
## Example Setup

context = gx.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": df})

expectation = gx.expectations.ExpectColumnValuesToBeBetween(
    column="passenger_count", min_value=1, max_value=6
)

validation_result = batch.validate(expectation)
# Out:
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmp0ub_vbo5' for ephemeral docs site
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# #**To-do:**
#
# 1.   Fetch any dataset from online source. I'll recommend using reddit API used in the assignment #1.
# 2.   Run 5 expectations of your choice to validate the dataset. They should cover row, column, multi-column, table, distribution operation.
# 3.   Submit the notebook file on LMS before Monday 11:55 PM.
# 4.   Mention your group number in the name of the file.

# %%
from google.colab import userdata

# %%
CLIENT_ID = userdata.get('REDDIT_CLIENT_ID')
CLIENT_SECRET = userdata.get('REDDIT_CLIENT_SECRET')
USER_AGENT = userdata.get('USER_AGENT')

# %%
URL = "https://www.reddit.com/r/Cricket/comments/17z01xd/australia_are_champions_of_the_2023_odi_world_cup/"

# %%
reddit = praw.Reddit(
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET,
    user_agent=USER_AGENT
)

# %%
submission = reddit.submission(url=URL)
submission.comments.replace_more(limit=0)

data = []
for comment in submission.comments.list()[:200]:

  data.append({
            "title": submission.title,
            "post_text": comment.body,  # Corrected to fetch comment text
            "author": comment.author.name if comment.author else "[deleted]",
            "date": comment.created_utc,
            "upvotes": comment.score,
            "subreddit": submission.subreddit.display_name
  })
df = pd.DataFrame(data)
df.to_csv('/content/reddit_data.csv',index=False)
print("Raw Reddit comments saved successfully!")
# Out:
# WARNING:praw:It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
# Raw Reddit comments saved successfully!

# %%
Df = pd.read_csv('/content/reddit_data.csv')

# %%
Df.head()
# Out:
#                                                title  \
# 0  Australia are champions of the 2023 ODI World Cup
# 1  Australia are champions of the 2023 ODI World Cup
# 2  Australia are champions of the 2023 ODI World Cup
# 3  Australia are champions of the 2023 ODI World Cup
# 4  Australia are champions of the 2023 ODI World Cup
#
#                                            post_text                author  \
# 0  Between his incredible catch that completely s...               sellyme
# 1  Dominating the entire tournament, nah mate, we...  Nice_Personality_254
# 2  The entire stadium is pin drop silent holy shi...              Bolt_995
# 3  Dread it. Run from it.\n\n*World Cup Australia...              limelamb
# 4  Knew Travis Head was a good egg after he spent...            BreakingTJ
#
#            date  upvotes subreddit
# 0  1.700409e+09     3138   Cricket
# 1  1.700409e+09     1524   Cricket
# 2  1.700410e+09      420   Cricket
# 3  1.700409e+09     1863   Cricket
# ...

# %%
context = gx.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": Df})

# expectation = gx.expectations.ExpectColumnValuesToBeBetween(
#     column="author", min_value=1, max_value=6
# )

# validation_result = batch.validate(expectation)
# Out:
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmpj72udl5g' for ephemeral docs site

# %%
expectation_one = gx.expectations.ExpectColumnToExist(column="author")
validation_result = batch.validate(expectation_one)
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
expectation_two = gx.expectations.ExpectTableRowCountToBeBetween(min_value=100, max_value=150)
validation_result = batch.validate(expectation_two)
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
expectation_three = gx.expectations.ExpectMulticolumnSumToEqual(column_list=["upvotes",'date'],sum_total=7)
validation_result = batch.validate(expectation_three)
# Out:
# Calculating Metrics:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
expectation_four = gx.expectations.ExpectColumnMedianToBeBetween(column="upvotes", min_value=100, max_value=150)
validation_result = batch.validate(expectation_four)
# Out:
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
expectation_five = gx.expectations.ExpectColumnValuesToBeDateutilParseable(column="date")
validation_result = batch.validate(expectation_five)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
